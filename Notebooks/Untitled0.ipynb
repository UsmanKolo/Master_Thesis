# %% [markdown]
# # PART 1. Data Pre-processing
# ## Step #0. Fire the system

# %%
# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
# from google.colab import drive 
# drive.mount('/content/drive')

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

# %matplotlib inline

# %% [markdown]
# ## Step #1. Read data

# %%
# Importing Training Set
df = pd.read_csv('QBElecWeather.csv', index_col=0, parse_dates=True)
df = df.resample(rule='D').mean()
df = df.loc[:'2019-12-30']
data = df.reset_index()

dataset_train = data.copy()

dataset_train
# Out:
#        Datetime        KW/h      temp  dew_point     pressure   humidity  \
# 0    2008-03-03  100.073667  4.422917  -0.175417  1010.041667  72.250000
# 1    2008-03-04  158.292792  3.310000  -0.861250  1026.375000  75.208333
# 2    2008-03-05  161.450042  4.049167   0.947083  1033.000000  80.291667
# 3    2008-03-06  158.311500  9.252500   5.157500  1021.916667  75.791667
# 4    2008-03-07  155.790375  7.638750   2.673333  1010.166667  71.750000
# ...         ...         ...       ...        ...          ...        ...
# 4315 2019-12-26   67.020833  4.358333   2.606250  1016.291667  88.375000
# 4316 2019-12-27   65.083333  5.761250   3.721667  1028.458333  86.708333
# 4317 2019-12-28   59.000000  7.845000   5.699167  1034.708333  86.291667
# 4318 2019-12-29   51.374958  6.718750   4.690417  1031.583333  86.875000
# 4319 2019-12-30   60.375000  5.649583   3.562500  1028.125000  86.458333
#
#       wind_speed
# 0       5.371667
# 1       5.100000
# 2       4.379167
# 3       5.761250
# 4       6.660833
# ...          ...
# 4315    4.367917
# 4316    2.554583
# 4317    4.385833
# 4318    5.037917
# 4319    4.234167
#
# [4320 rows x 7 columns]

# %%
# Select features (columns) to be involved intro training and predictions
cols = list(dataset_train)[1:7]

# Extract dates (will be used in visualization)
datelist_train = list(dataset_train['Datetime'])
# datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

print('Training set shape == {}'.format(dataset_train.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(cols))
# Out:
# Training set shape == (4320, 7)
# All timestamps == 4320
# Featured selected: ['KW/h', 'temp', 'dew_point', 'pressure', 'humidity', 'wind_speed']

# %% [markdown]
# ## Step #2. Data pre-processing
# Removing all commas and convert data to matrix shape format.

# %%
dataset_train = dataset_train[cols].astype(str)
for i in cols:
    for j in range(0, len(dataset_train)):
        dataset_train[i][j] = dataset_train[i][j].replace(',', '')

dataset_train = dataset_train.astype(float)

# Using multiple features (predictors)
training_set = dataset_train.values

print('Shape of training set == {}.'.format(training_set.shape))
training_set[:1]
# Out:
# Shape of training set == (4320, 6).
# array([[ 1.00073667e+02,  4.42291667e+00, -1.75416667e-01,
#          1.01004167e+03,  7.22500000e+01,  5.37166667e+00]])

# %%
# Feature Scaling
from sklearn.preprocessing import *

sc = MinMaxScaler()
training_set_scaled = sc.fit_transform(training_set)

sc_predict = MinMaxScaler()
sc_predict.fit_transform(training_set[:, 0:1])
# Out:
# array([[0.40334369],
#        [0.86616533],
#        [0.89126436],
#        ...,
#        [0.07682243],
#        [0.01620602],
#        [0.0877532 ]])

# %%
# Creating a data structure with 90 timestamps and 1 output
X_train = []
y_train = []

n_future = 860  # Number of days we want top predict into the future
n_past = 29     # Number of past days we want to use to predict the future

for i in range(n_past, len(training_set_scaled) - n_future +1):
    X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
    y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (3432, 29, 5).
# y_train shape == (3432, 1).

# %% [markdown]
# # PART 2. Create a model. Training
# ## Step #3. Building the LSTM based Neural Network

# %%
# Import Libraries and packages from Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Bidirectional
from keras.layers import Dropout
# from keras.optimizer_v1 import Adam

# %%
# # Initializing the Neural Network based on LSTM
# model = Sequential()

# # Adding 1st LSTM layer
# model.add(LSTM(units=128, activation='relu', return_sequences=True, input_shape=(n_past, dataset_train.shape[1]-1)))

# # Adding 2nd LSTM layer
# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=False))

# # Adding Dropout
# model.add(Dropout(0.2))

# # Output layer
# # model.add(Dense(units=64, activation='relu'))

# model.add(Dense(units=1))

# model = Sequential()
# model.add(LSTM(units=128, activation='relu', input_shape=(n_past, dataset_train.shape[1]-1), return_sequences=True))
# model.add(LSTM(units=128, activation='relu'))
# model.add(Dropout(rate=0.2))
# # model.add(Dense(units=8, activation='relu'))
# model.add(Dense(units=1))
# model.summary()

model = Sequential()
model.add(Bidirectional(LSTM(units=128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True)))
model.add(Bidirectional(LSTM(units=128)))
model.add(Dropout(rate=0.5))
model.add(Dense(units=1))

# Compiling the Neural Network
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Step #4. Start training

# %%
# %%time
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

history = model.fit(X_train, y_train, shuffle=False, epochs=100, callbacks=[es, rlr, mcp, tb], validation_split=0.1, verbose=1, batch_size=64)
# Out:
# Epoch 1/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0536
# Epoch 1: val_loss improved from inf to 0.02526, saving model to weights.h5
# 49/49 [==============================] - 17s 133ms/step - loss: 0.0535 - val_loss: 0.0253 - lr: 0.0010
# Epoch 2/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0287
# Epoch 2: val_loss improved from 0.02526 to 0.02309, saving model to weights.h5
# 49/49 [==============================] - 5s 93ms/step - loss: 0.0286 - val_loss: 0.0231 - lr: 0.0010
# Epoch 3/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0281
# Epoch 3: val_loss improved from 0.02309 to 0.02199, saving model to weights.h5
# 49/49 [==============================] - 5s 92ms/step - loss: 0.0281 - val_loss: 0.0220 - lr: 0.0010
# Epoch 4/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0277
# Epoch 4: val_loss improved from 0.02199 to 0.02163, saving model to weights.h5
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0277 - val_loss: 0.0216 - lr: 0.0010
# Epoch 5/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0270
# Epoch 5: val_loss did not improve from 0.02163
# 49/49 [==============================] - 5s 93ms/step - loss: 0.0271 - val_loss: 0.0223 - lr: 0.0010
# Epoch 6/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0271
# Epoch 6: val_loss improved from 0.02163 to 0.02141, saving model to weights.h5
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0271 - val_loss: 0.0214 - lr: 0.0010
# Epoch 7/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0264
# Epoch 7: val_loss did not improve from 0.02141
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0264 - val_loss: 0.0217 - lr: 0.0010
# Epoch 8/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 8: val_loss improved from 0.02141 to 0.02082, saving model to weights.h5
# 49/49 [==============================] - 4s 77ms/step - loss: 0.0261 - val_loss: 0.0208 - lr: 0.0010
# Epoch 9/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 9: val_loss improved from 0.02082 to 0.02078, saving model to weights.h5
# 49/49 [==============================] - 4s 81ms/step - loss: 0.0261 - val_loss: 0.0208 - lr: 0.0010
# Epoch 10/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 10: val_loss improved from 0.02078 to 0.02060, saving model to weights.h5
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0261 - val_loss: 0.0206 - lr: 0.0010
# Epoch 11/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0259
# Epoch 11: val_loss did not improve from 0.02060
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0259 - val_loss: 0.0209 - lr: 0.0010
# Epoch 12/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0256
# Epoch 12: val_loss improved from 0.02060 to 0.01990, saving model to weights.h5
# 49/49 [==============================] - 5s 93ms/step - loss: 0.0256 - val_loss: 0.0199 - lr: 0.0010
# Epoch 13/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0250
# Epoch 13: val_loss did not improve from 0.01990
# 49/49 [==============================] - 5s 92ms/step - loss: 0.0250 - val_loss: 0.0199 - lr: 0.0010
# Epoch 14/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0246
# Epoch 14: val_loss improved from 0.01990 to 0.01932, saving model to weights.h5
# 49/49 [==============================] - 4s 92ms/step - loss: 0.0246 - val_loss: 0.0193 - lr: 0.0010
# Epoch 15/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0246
# Epoch 15: val_loss did not improve from 0.01932
# 49/49 [==============================] - 5s 94ms/step - loss: 0.0246 - val_loss: 0.0195 - lr: 0.0010
# Epoch 16/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0239
# Epoch 16: val_loss improved from 0.01932 to 0.01909, saving model to weights.h5
# 49/49 [==============================] - 5s 95ms/step - loss: 0.0239 - val_loss: 0.0191 - lr: 0.0010
# Epoch 17/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0239
# Epoch 17: val_loss improved from 0.01909 to 0.01780, saving model to weights.h5
# 49/49 [==============================] - 5s 96ms/step - loss: 0.0239 - val_loss: 0.0178 - lr: 0.0010
# Epoch 18/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0233
# Epoch 18: val_loss did not improve from 0.01780
# 49/49 [==============================] - 5s 94ms/step - loss: 0.0233 - val_loss: 0.0181 - lr: 0.0010
# Epoch 19/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0229
# Epoch 19: val_loss improved from 0.01780 to 0.01632, saving model to weights.h5
# 49/49 [==============================] - 5s 95ms/step - loss: 0.0229 - val_loss: 0.0163 - lr: 0.0010
# Epoch 20/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0224
# Epoch 20: val_loss improved from 0.01632 to 0.01622, saving model to weights.h5
# 49/49 [==============================] - 5s 97ms/step - loss: 0.0224 - val_loss: 0.0162 - lr: 0.0010
# Epoch 21/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 21: val_loss improved from 0.01622 to 0.01515, saving model to weights.h5
# 49/49 [==============================] - 5s 95ms/step - loss: 0.0216 - val_loss: 0.0151 - lr: 0.0010
# Epoch 22/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0214
# Epoch 22: val_loss improved from 0.01515 to 0.01415, saving model to weights.h5
# 49/49 [==============================] - 5s 95ms/step - loss: 0.0214 - val_loss: 0.0141 - lr: 0.0010
# Epoch 23/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0208
# Epoch 23: val_loss improved from 0.01415 to 0.01352, saving model to weights.h5
# 49/49 [==============================] - 5s 95ms/step - loss: 0.0208 - val_loss: 0.0135 - lr: 0.0010
# Epoch 24/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0202
# Epoch 24: val_loss improved from 0.01352 to 0.01292, saving model to weights.h5
# 49/49 [==============================] - 5s 97ms/step - loss: 0.0202 - val_loss: 0.0129 - lr: 0.0010
# Epoch 25/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0199
# Epoch 25: val_loss improved from 0.01292 to 0.01250, saving model to weights.h5
# 49/49 [==============================] - 5s 97ms/step - loss: 0.0199 - val_loss: 0.0125 - lr: 0.0010
# Epoch 26/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0195
# Epoch 26: val_loss improved from 0.01250 to 0.01194, saving model to weights.h5
# 49/49 [==============================] - 5s 97ms/step - loss: 0.0195 - val_loss: 0.0119 - lr: 0.0010
# Epoch 27/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0192
# Epoch 27: val_loss improved from 0.01194 to 0.01184, saving model to weights.h5
# 49/49 [==============================] - 5s 98ms/step - loss: 0.0192 - val_loss: 0.0118 - lr: 0.0010
# Epoch 28/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0195
# Epoch 28: val_loss improved from 0.01184 to 0.01178, saving model to weights.h5
# 49/49 [==============================] - 5s 98ms/step - loss: 0.0195 - val_loss: 0.0118 - lr: 0.0010
# Epoch 29/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0194
# Epoch 29: val_loss improved from 0.01178 to 0.01163, saving model to weights.h5
# 49/49 [==============================] - 5s 98ms/step - loss: 0.0194 - val_loss: 0.0116 - lr: 0.0010
# Epoch 30/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0195
# Epoch 30: val_loss improved from 0.01163 to 0.01147, saving model to weights.h5
# 49/49 [==============================] - 5s 100ms/step - loss: 0.0195 - val_loss: 0.0115 - lr: 0.0010
# Epoch 31/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0195
# Epoch 31: val_loss improved from 0.01147 to 0.01143, saving model to weights.h5
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0194 - val_loss: 0.0114 - lr: 0.0010
# Epoch 32/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0191
# Epoch 32: val_loss improved from 0.01143 to 0.01103, saving model to weights.h5
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0191 - val_loss: 0.0110 - lr: 0.0010
# Epoch 33/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0191
# Epoch 33: val_loss did not improve from 0.01103
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0191 - val_loss: 0.0116 - lr: 0.0010
# Epoch 34/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0190
# Epoch 34: val_loss did not improve from 0.01103
# 49/49 [==============================] - 5s 100ms/step - loss: 0.0190 - val_loss: 0.0111 - lr: 0.0010
# Epoch 35/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0190
# Epoch 35: val_loss improved from 0.01103 to 0.01101, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0190 - val_loss: 0.0110 - lr: 0.0010
# Epoch 36/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0188
# Epoch 36: val_loss improved from 0.01101 to 0.01030, saving model to weights.h5
# 49/49 [==============================] - 5s 101ms/step - loss: 0.0188 - val_loss: 0.0103 - lr: 0.0010
# Epoch 37/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0190
# Epoch 37: val_loss did not improve from 0.01030
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0189 - val_loss: 0.0105 - lr: 0.0010
# Epoch 38/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0184
# Epoch 38: val_loss improved from 0.01030 to 0.00941, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0184 - val_loss: 0.0094 - lr: 0.0010
# Epoch 39/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0180
# Epoch 39: val_loss improved from 0.00941 to 0.00939, saving model to weights.h5
# 49/49 [==============================] - 5s 101ms/step - loss: 0.0180 - val_loss: 0.0094 - lr: 0.0010
# Epoch 40/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 40: val_loss improved from 0.00939 to 0.00905, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0181 - val_loss: 0.0091 - lr: 0.0010
# Epoch 41/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0178
# Epoch 41: val_loss improved from 0.00905 to 0.00888, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0177 - val_loss: 0.0089 - lr: 0.0010
# Epoch 42/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 42: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0177 - val_loss: 0.0096 - lr: 0.0010
# Epoch 43/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 43: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 104ms/step - loss: 0.0170 - val_loss: 0.0093 - lr: 0.0010
# Epoch 44/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 44: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0169 - val_loss: 0.0095 - lr: 0.0010
# Epoch 45/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 45: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 107ms/step - loss: 0.0166 - val_loss: 0.0092 - lr: 0.0010
# Epoch 46/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 46: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0164 - val_loss: 0.0093 - lr: 0.0010
# Epoch 47/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 47: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0166 - val_loss: 0.0092 - lr: 0.0010
# Epoch 48/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 48: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 108ms/step - loss: 0.0162 - val_loss: 0.0094 - lr: 0.0010
# Epoch 49/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0163
# Epoch 49: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0162 - val_loss: 0.0100 - lr: 0.0010
# Epoch 50/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 50: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0166 - val_loss: 0.0097 - lr: 0.0010
# Epoch 51/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 51: val_loss did not improve from 0.00888
# 49/49 [==============================] - 5s 108ms/step - loss: 0.0168 - val_loss: 0.0091 - lr: 0.0010
# Epoch 51: early stopping
# Wall time: 4min 15s

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend();

# %% [markdown]
# ## PART 3. Make future predictions

# %%
# Generate list of sequence of days for predictions
datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()

'''
Remeber, we have datelist_train from begining.
'''

# Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
datelist_future_ = []
for this_timestamp in datelist_future:
    datelist_future_.append(this_timestamp.date())

# %% [markdown]
# ## Step #5. Make predictions for future dates

# %%
# Perform predictions
predictions_future = model.predict(X_train[-n_future:])

predictions_train = model.predict(X_train[n_past:])

predictions_train1 = model.predict(X_train)

# %% [markdown]
# ## Step #6. Evaluate Metrics

# %%
from sklearn.metrics import *

print('RMSE: ', np.sqrt(mean_squared_error(y_train, predictions_train1)))
print('MSE: ', mean_squared_error(y_train, predictions_train1))
print('MAE: ', mean_absolute_error(y_train, predictions_train1))
print('R2: ', r2_score(y_train, predictions_train1)*100)
# Out:
# RMSE:  0.14501915578029662
# MSE:  0.021030555543229936
# MAE:  0.11795006224435081
# R2:  19.24661016711725

# %%
# Inverse the predictions to original measurements

# ---> Special function: convert <datetime.date> to <Timestamp>
def datetime_to_timestamp(x):
    '''
        x : a given datetime value (datetime.date)
    '''
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')


y_pred_future = sc_predict.inverse_transform(predictions_future)
y_pred_train = sc_predict.inverse_transform(predictions_train)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['value']).set_index(pd.Series(datelist_future))
PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['value']).set_index(pd.Series(datelist_train[2 * n_past + n_future -1:]))

# Convert <datetime.date> to <Timestamp> for PREDCITION_TRAIN
PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)

PREDICTION_TRAIN.head(3)
# Out:
#                  value
# 2010-09-06  104.550690
# 2010-09-07  106.689972
# 2010-09-08  106.936691

# %%
datelist_train = pd.to_datetime(datelist_train)

# %%
dataset_train = dataset_train.set_index(datelist_train)

# %%
dataset_train.head()
# Out:
#                   KW/h      temp  dew_point     pressure   humidity  \
# 2008-03-03  100.073667  4.422917  -0.175417  1010.041667  72.250000
# 2008-03-04  158.292792  3.310000  -0.861250  1026.375000  75.208333
# 2008-03-05  161.450042  4.049167   0.947083  1033.000000  80.291667
# 2008-03-06  158.311500  9.252500   5.157500  1021.916667  75.791667
# 2008-03-07  155.790375  7.638750   2.673333  1010.166667  71.750000
#
#             wind_speed
# 2008-03-03    5.371667
# 2008-03-04    5.100000
# 2008-03-05    4.379167
# 2008-03-06    5.761250
# 2008-03-07    6.660833

# %% [markdown]
# ## Step #6. Visualize the Predictions

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 20, 9

# Plot parameters
START_DATE_FOR_PLOTTING = '2018-01-01'

plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['value'], color='r', label='Predicted Reading')
plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['value'], color='orange', label='Training predictions')
plt.plot(dataset_train.loc[START_DATE_FOR_PLOTTING:].index, dataset_train.loc[START_DATE_FOR_PLOTTING:]['KW/h'], color='b', label='Actual Reading')

plt.axvline(x = min(PREDICTIONS_FUTURE.index), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Predcitions and Acutal Queens Building', family='Arial', fontsize=14, fontweight='bold')
plt.xlabel('Timeline', family='Arial', fontsize=12, fontweight='bold')
plt.ylabel('Energy Reading', family='Arial', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, fontsize=8)
plt.show()
