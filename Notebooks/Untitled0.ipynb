# %% [markdown]
# # PART 1. Data Pre-processing
# ## Step #0. Fire the system

# %%
# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (13,10)
plt.style.use('bmh')
import datetime as dt
from datetime import datetime
# from google.colab import drive 
# drive.mount('/content/drive')

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

# %matplotlib inline

# %% [markdown]
# ## Step #1. Read data

# %%
# Importing Training Set
df = pd.read_csv('C:\\Users\\moham\\OneDrive - De Montfort University\\Final Project\\Master_Thesis\\Dataset\\QBElecWeatherDailyData.csv', index_col=0, parse_dates=True)

# %%
df.plot(subplots=True, figsize=(13,9), title='QB Electricity')
# Out:
# array([<AxesSubplot:xlabel='Datetime'>, <AxesSubplot:xlabel='Datetime'>,
#        <AxesSubplot:xlabel='Datetime'>, <AxesSubplot:xlabel='Datetime'>,
#        <AxesSubplot:xlabel='Datetime'>, <AxesSubplot:xlabel='Datetime'>],
#       dtype=object)

# %%
df = df.loc[:'2019-12-30']
data = df.reset_index()

dataset_train = data.copy()

dataset_train

# %%
# Select features (columns) to be involved intro training and predictions
cols = list(dataset_train)[1:7]

# Extract dates (will be used in visualization)
datelist_train = list(dataset_train['Datetime'])
# datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

print('Training set shape == {}'.format(dataset_train.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(cols))
# Out:
# Training set shape == (4320, 7)
# All timestamps == 4320
# Featured selected: ['value', 'temp', 'dew_point', 'pressure', 'humidity', 'wind_speed']

# %% [markdown]
# ## Step #2. Data pre-processing
# Removing all commas and convert data to matrix shape format.

# %%
dataset_train = dataset_train[cols].astype(str)
for i in cols:
    for j in range(0, len(dataset_train)):
        dataset_train[i][j] = dataset_train[i][j].replace(',', '')

dataset_train = dataset_train.astype(float)

# Using multiple features (predictors)
training_set = dataset_train.values

print('Shape of training set == {}.'.format(training_set.shape))
training_set[:1]
# Out:
# Shape of training set == (4320, 6).
# array([[ 2.40176800e+03,  4.42291667e+00, -1.75416667e-01,
#          1.01004167e+03,  7.22500000e+01,  5.37166667e+00]])

# %%
# Feature Scaling
from sklearn.preprocessing import *

sc = MinMaxScaler()
training_set_scaled = sc.fit_transform(training_set)

sc_predict = MinMaxScaler()
sc_predict.fit_transform(training_set[:, 0:1])
# Out:
# array([[0.40334369],
#        [0.86616533],
#        [0.89126436],
#        ...,
#        [0.07682243],
#        [0.01620602],
#        [0.0877532 ]])

# %%
# Creating a data structure with 90 timestamps and 1 output
X_train = []
y_train = []

n_future = 860  # Number of days we want top predict into the future
n_past = 30     # Number of past days we want to use to predict the future

for i in range(n_past, len(training_set_scaled) - n_future +1):
    X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
    y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (3431, 30, 5).
# y_train shape == (3431, 1).

# %% [markdown]
# # PART 2. Create a model. Training
# ## Step #3. Building the LSTM based Neural Network

# %%
# Import Libraries and packages from Keras
from keras.models import *
from keras.layers import *

# %%
# # Initializing the Neural Network based on LSTM
# model = Sequential()

# # Adding 1st LSTM layer
# model.add(LSTM(units=128, activation='relu', return_sequences=True, input_shape=(n_past, dataset_train.shape[1]-1)))

# # Adding 2nd LSTM layer
# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=False))

# # Adding Dropout
# model.add(Dropout(0.2))

# # Output layer
# # model.add(Dense(units=64, activation='relu'))

# model.add(Dense(units=1))

# model = Sequential()
# model.add(LSTM(units=128, activation='relu', input_shape=(n_past, dataset_train.shape[1]-1), return_sequences=True))
# model.add(LSTM(units=128, activation='relu'))
# model.add(Dropout(rate=0.2))
# # model.add(Dense(units=8, activation='relu'))
# model.add(Dense(units=1))
# model.summary()

model = Sequential()
model.add(Bidirectional(LSTM(units=128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True)))
model.add(Bidirectional(LSTM(units=128)))
model.add(Dropout(rate=0.2))
model.add(Dense(units=1))

# Compiling the Neural Network
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Step #4. Start training

# %%
# %%time
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

history = model.fit(X_train, y_train, shuffle=False, epochs=100, callbacks=[es, rlr, mcp, tb], validation_split=0.1, verbose=1, batch_size=32)
# Out:
# Epoch 1/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0559
# Epoch 1: val_loss improved from inf to 0.02284, saving model to weights.h5
# 49/49 [==============================] - 16s 126ms/step - loss: 0.0557 - val_loss: 0.0228 - lr: 0.0010
# Epoch 2/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0265
# Epoch 2: val_loss improved from 0.02284 to 0.02243, saving model to weights.h5
# 49/49 [==============================] - 4s 89ms/step - loss: 0.0265 - val_loss: 0.0224 - lr: 0.0010
# Epoch 3/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0265
# Epoch 3: val_loss improved from 0.02243 to 0.02183, saving model to weights.h5
# 49/49 [==============================] - 5s 96ms/step - loss: 0.0265 - val_loss: 0.0218 - lr: 0.0010
# Epoch 4/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 4: val_loss improved from 0.02183 to 0.02134, saving model to weights.h5
# 49/49 [==============================] - 5s 96ms/step - loss: 0.0261 - val_loss: 0.0213 - lr: 0.0010
# Epoch 5/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0254
# Epoch 5: val_loss improved from 0.02134 to 0.02127, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0254 - val_loss: 0.0213 - lr: 0.0010
# Epoch 6/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0252
# Epoch 6: val_loss improved from 0.02127 to 0.02070, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0251 - val_loss: 0.0207 - lr: 0.0010
# Epoch 7/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0246
# Epoch 7: val_loss improved from 0.02070 to 0.02069, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0246 - val_loss: 0.0207 - lr: 0.0010
# Epoch 8/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0240
# Epoch 8: val_loss improved from 0.02069 to 0.01950, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0240 - val_loss: 0.0195 - lr: 0.0010
# Epoch 9/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0238
# Epoch 9: val_loss did not improve from 0.01950
# 49/49 [==============================] - 5s 104ms/step - loss: 0.0238 - val_loss: 0.0197 - lr: 0.0010
# Epoch 10/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0233
# Epoch 10: val_loss improved from 0.01950 to 0.01876, saving model to weights.h5
# 49/49 [==============================] - 5s 101ms/step - loss: 0.0233 - val_loss: 0.0188 - lr: 0.0010
# Epoch 11/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0227
# Epoch 11: val_loss improved from 0.01876 to 0.01799, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0227 - val_loss: 0.0180 - lr: 0.0010
# Epoch 12/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0223
# Epoch 12: val_loss improved from 0.01799 to 0.01781, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0223 - val_loss: 0.0178 - lr: 0.0010
# Epoch 13/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0223
# Epoch 13: val_loss improved from 0.01781 to 0.01733, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0223 - val_loss: 0.0173 - lr: 0.0010
# Epoch 14/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0216
# Epoch 14: val_loss improved from 0.01733 to 0.01665, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0216 - val_loss: 0.0166 - lr: 0.0010
# Epoch 15/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0214
# Epoch 15: val_loss improved from 0.01665 to 0.01620, saving model to weights.h5
# 49/49 [==============================] - 5s 100ms/step - loss: 0.0214 - val_loss: 0.0162 - lr: 0.0010
# Epoch 16/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0204
# Epoch 16: val_loss improved from 0.01620 to 0.01499, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0204 - val_loss: 0.0150 - lr: 0.0010
# Epoch 17/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0203
# Epoch 17: val_loss improved from 0.01499 to 0.01459, saving model to weights.h5
# 49/49 [==============================] - 5s 101ms/step - loss: 0.0203 - val_loss: 0.0146 - lr: 0.0010
# Epoch 18/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0198
# Epoch 18: val_loss improved from 0.01459 to 0.01437, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0198 - val_loss: 0.0144 - lr: 0.0010
# Epoch 19/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 19: val_loss improved from 0.01437 to 0.01369, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0196 - val_loss: 0.0137 - lr: 0.0010
# Epoch 20/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0192
# Epoch 20: val_loss improved from 0.01369 to 0.01328, saving model to weights.h5
# 49/49 [==============================] - 5s 104ms/step - loss: 0.0191 - val_loss: 0.0133 - lr: 0.0010
# Epoch 21/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0186
# Epoch 21: val_loss improved from 0.01328 to 0.01289, saving model to weights.h5
# 49/49 [==============================] - 5s 104ms/step - loss: 0.0186 - val_loss: 0.0129 - lr: 0.0010
# Epoch 22/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0184
# Epoch 22: val_loss improved from 0.01289 to 0.01270, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0184 - val_loss: 0.0127 - lr: 0.0010
# Epoch 23/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 23: val_loss improved from 0.01270 to 0.01250, saving model to weights.h5
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0185 - val_loss: 0.0125 - lr: 0.0010
# Epoch 24/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 24: val_loss improved from 0.01250 to 0.01236, saving model to weights.h5
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0181 - val_loss: 0.0124 - lr: 0.0010
# Epoch 25/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 25: val_loss improved from 0.01236 to 0.01190, saving model to weights.h5
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0180 - val_loss: 0.0119 - lr: 0.0010
# Epoch 26/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 26: val_loss improved from 0.01190 to 0.01178, saving model to weights.h5
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0181 - val_loss: 0.0118 - lr: 0.0010
# Epoch 27/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0176
# Epoch 27: val_loss improved from 0.01178 to 0.01160, saving model to weights.h5
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0175 - val_loss: 0.0116 - lr: 0.0010
# Epoch 28/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 28: val_loss improved from 0.01160 to 0.01117, saving model to weights.h5
# 49/49 [==============================] - 5s 104ms/step - loss: 0.0175 - val_loss: 0.0112 - lr: 0.0010
# Epoch 29/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 29: val_loss improved from 0.01117 to 0.01097, saving model to weights.h5
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0175 - val_loss: 0.0110 - lr: 0.0010
# Epoch 30/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 30: val_loss improved from 0.01097 to 0.01070, saving model to weights.h5
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0173 - val_loss: 0.0107 - lr: 0.0010
# Epoch 31/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 31: val_loss improved from 0.01070 to 0.01059, saving model to weights.h5
# 49/49 [==============================] - 5s 104ms/step - loss: 0.0174 - val_loss: 0.0106 - lr: 0.0010
# Epoch 32/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 32: val_loss improved from 0.01059 to 0.01038, saving model to weights.h5
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0170 - val_loss: 0.0104 - lr: 0.0010
# Epoch 33/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 33: val_loss did not improve from 0.01038
# 49/49 [==============================] - 5s 107ms/step - loss: 0.0174 - val_loss: 0.0108 - lr: 0.0010
# Epoch 34/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 34: val_loss improved from 0.01038 to 0.01012, saving model to weights.h5
# 49/49 [==============================] - 5s 107ms/step - loss: 0.0171 - val_loss: 0.0101 - lr: 0.0010
# Epoch 35/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 35: val_loss did not improve from 0.01012
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0172 - val_loss: 0.0104 - lr: 0.0010
# Epoch 36/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0173
# Epoch 36: val_loss improved from 0.01012 to 0.01005, saving model to weights.h5
# 49/49 [==============================] - 5s 109ms/step - loss: 0.0173 - val_loss: 0.0101 - lr: 0.0010
# Epoch 37/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0169
# Epoch 37: val_loss improved from 0.01005 to 0.00937, saving model to weights.h5
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0168 - val_loss: 0.0094 - lr: 0.0010
# Epoch 38/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 38: val_loss did not improve from 0.00937
# 49/49 [==============================] - 5s 108ms/step - loss: 0.0167 - val_loss: 0.0100 - lr: 0.0010
# Epoch 39/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 39: val_loss did not improve from 0.00937
# 49/49 [==============================] - 5s 107ms/step - loss: 0.0173 - val_loss: 0.0103 - lr: 0.0010
# Epoch 40/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 40: val_loss did not improve from 0.00937
# 49/49 [==============================] - 5s 107ms/step - loss: 0.0170 - val_loss: 0.0103 - lr: 0.0010
# Epoch 41/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 41: val_loss did not improve from 0.00937
# 49/49 [==============================] - 5s 108ms/step - loss: 0.0170 - val_loss: 0.0096 - lr: 0.0010
# Epoch 42/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 42: val_loss did not improve from 0.00937
# 49/49 [==============================] - 5s 109ms/step - loss: 0.0168 - val_loss: 0.0101 - lr: 0.0010
# Epoch 43/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 43: val_loss improved from 0.00937 to 0.00895, saving model to weights.h5
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0166 - val_loss: 0.0089 - lr: 0.0010
# Epoch 44/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 44: val_loss did not improve from 0.00895
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0165 - val_loss: 0.0097 - lr: 0.0010
# Epoch 45/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 45: val_loss did not improve from 0.00895
# 49/49 [==============================] - 5s 109ms/step - loss: 0.0166 - val_loss: 0.0094 - lr: 0.0010
# Epoch 46/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 46: val_loss did not improve from 0.00895
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0169 - val_loss: 0.0096 - lr: 0.0010
# Epoch 47/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 47: val_loss improved from 0.00895 to 0.00852, saving model to weights.h5
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0166 - val_loss: 0.0085 - lr: 0.0010
# Epoch 48/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 48: val_loss did not improve from 0.00852
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0166 - val_loss: 0.0092 - lr: 0.0010
# Epoch 49/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 49: val_loss improved from 0.00852 to 0.00840, saving model to weights.h5
# 49/49 [==============================] - 6s 114ms/step - loss: 0.0165 - val_loss: 0.0084 - lr: 0.0010
# Epoch 50/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 50: val_loss did not improve from 0.00840
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0166 - val_loss: 0.0089 - lr: 0.0010
# Epoch 51/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 51: val_loss improved from 0.00840 to 0.00834, saving model to weights.h5
# 49/49 [==============================] - 6s 115ms/step - loss: 0.0164 - val_loss: 0.0083 - lr: 0.0010
# Epoch 52/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 52: val_loss did not improve from 0.00834
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0165 - val_loss: 0.0086 - lr: 0.0010
# Epoch 53/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0169
# Epoch 53: val_loss did not improve from 0.00834
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0168 - val_loss: 0.0084 - lr: 0.0010
# Epoch 54/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 54: val_loss did not improve from 0.00834
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0162 - val_loss: 0.0084 - lr: 0.0010
# Epoch 55/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 55: val_loss improved from 0.00834 to 0.00817, saving model to weights.h5
# 49/49 [==============================] - 6s 118ms/step - loss: 0.0166 - val_loss: 0.0082 - lr: 0.0010
# Epoch 56/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 56: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0161 - val_loss: 0.0086 - lr: 0.0010
# Epoch 57/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 57: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 119ms/step - loss: 0.0159 - val_loss: 0.0083 - lr: 0.0010
# Epoch 58/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 58: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 118ms/step - loss: 0.0158 - val_loss: 0.0083 - lr: 0.0010
# Epoch 59/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 59: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 121ms/step - loss: 0.0160 - val_loss: 0.0088 - lr: 0.0010
# Epoch 60/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 60: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 121ms/step - loss: 0.0159 - val_loss: 0.0091 - lr: 0.0010
# Epoch 61/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 61: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 121ms/step - loss: 0.0156 - val_loss: 0.0100 - lr: 0.0010
# Epoch 62/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 62: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 121ms/step - loss: 0.0155 - val_loss: 0.0097 - lr: 0.0010
# Epoch 63/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0153
# Epoch 63: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 122ms/step - loss: 0.0152 - val_loss: 0.0100 - lr: 0.0010
# Epoch 64/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0152
# Epoch 64: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 117ms/step - loss: 0.0152 - val_loss: 0.0101 - lr: 0.0010
# Epoch 65/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 65: val_loss did not improve from 0.00817
# 49/49 [==============================] - 6s 120ms/step - loss: 0.0151 - val_loss: 0.0113 - lr: 0.0010
# Epoch 65: early stopping
# Wall time: 5min 55s

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend();

# %% [markdown]
# ## PART 3. Make future predictions

# %%
# Generate list of sequence of days for predictions
datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()

'''
Remeber, we have datelist_train from begining.
'''

# Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
datelist_future_ = []
for this_timestamp in datelist_future:
    datelist_future_.append(this_timestamp.date())

# %% [markdown]
# ## Step #5. Make predictions for future dates

# %%
# Perform predictions
predictions_future = model.predict(X_train[-n_future:])

predictions_train = model.predict(X_train[n_past:])

predictions_train1 = model.predict(X_train)

# %% [markdown]
# ## Step #6. Evaluate Metrics

# %%
from sklearn.metrics import *

print('RMSE: ', np.sqrt(mean_squared_error(y_train, predictions_train1)))
print('MSE: ', mean_squared_error(y_train, predictions_train1))
print('MAE: ', mean_absolute_error(y_train, predictions_train1))
print('R2: ', r2_score(y_train, predictions_train1)*100)
# Out:
# RMSE:  0.13885619496277649
# MSE:  0.01928104287954059
# MAE:  0.11162019367215817
# R2:  25.98207942886619

# %%
# Inverse the predictions to original measurements

# ---> Special function: convert <datetime.date> to <Timestamp>
def datetime_to_timestamp(x):
    '''
        x : a given datetime value (datetime.date)
    '''
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')


y_pred_future = sc_predict.inverse_transform(predictions_future)
y_pred_train = sc_predict.inverse_transform(predictions_train)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['value']).set_index(pd.Series(datelist_future))
PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['value']).set_index(pd.Series(datelist_train[2 * n_past + n_future -1:]))

# Convert <datetime.date> to <Timestamp> for PREDCITION_TRAIN
PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)

PREDICTION_TRAIN.head(3)
# Out:
#                   value
# 2010-09-08  2518.883301
# 2010-09-09  2493.766113
# 2010-09-10  2417.651367

# %%
datelist_train = pd.to_datetime(datelist_train)

# %%
dataset_train = dataset_train.set_index(datelist_train)

# %%
dataset_train.head()
# Out:
#                value      temp  dew_point     pressure   humidity  wind_speed
# 2008-03-03  2401.768  4.422917  -0.175417  1010.041667  72.250000    5.371667
# 2008-03-04  3799.027  3.310000  -0.861250  1026.375000  75.208333    5.100000
# 2008-03-05  3874.801  4.049167   0.947083  1033.000000  80.291667    4.379167
# 2008-03-06  3799.476  9.252500   5.157500  1021.916667  75.791667    5.761250
# 2008-03-07  3738.969  7.638750   2.673333  1010.166667  71.750000    6.660833

# %% [markdown]
# ## Step #6. Visualize the Predictions

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 20, 9

# Plot parameters
START_DATE_FOR_PLOTTING = '2018-01-01'

plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['value'], color='r', label='Predicted Reading')
plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['value'], color='orange', label='Training predictions')
plt.plot(dataset_train.loc[START_DATE_FOR_PLOTTING:].index, dataset_train.loc[START_DATE_FOR_PLOTTING:]['value'], color='b', label='Actual Reading')

plt.axvline(x = min(PREDICTIONS_FUTURE.index), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Predcitions and Acutal Queens Building', family='Arial', fontsize=14, fontweight='bold')
plt.xlabel('Timeline', family='Arial', fontsize=12, fontweight='bold')
plt.ylabel('Energy Reading', family='Arial', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, fontsize=8)
plt.show()
