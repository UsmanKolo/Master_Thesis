# %% [markdown]
# # PART 1. Data Pre-processing
# ## Step #0. Fire the system

# %%
# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
# from google.colab import drive 
# drive.mount('/content/drive')

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

# %matplotlib inline

# %% [markdown]
# ## Step #1. Read data

# %%
# Importing Training Set
df = pd.read_csv('C:\\Users\\moham\\OneDrive - De Montfort University\\Final Project\\Master_Thesis\\Dataset\\QBElecWeather.csv', index_col=0, parse_dates=True)
df = df.resample(rule='D').mean()
df = df.loc[:'2019-12-30']
data = df.reset_index()

dataset_train = data.copy()

dataset_train
# Out:
#        Datetime        KW/h      temp  dew_point     pressure   humidity  \
# 0    2008-03-03  100.073667  4.422917  -0.175417  1010.041667  72.250000
# 1    2008-03-04  158.292792  3.310000  -0.861250  1026.375000  75.208333
# 2    2008-03-05  161.450042  4.049167   0.947083  1033.000000  80.291667
# 3    2008-03-06  158.311500  9.252500   5.157500  1021.916667  75.791667
# 4    2008-03-07  155.790375  7.638750   2.673333  1010.166667  71.750000
# ...         ...         ...       ...        ...          ...        ...
# 4315 2019-12-26   67.020833  4.358333   2.606250  1016.291667  88.375000
# 4316 2019-12-27   65.083333  5.761250   3.721667  1028.458333  86.708333
# 4317 2019-12-28   59.000000  7.845000   5.699167  1034.708333  86.291667
# 4318 2019-12-29   51.374958  6.718750   4.690417  1031.583333  86.875000
# 4319 2019-12-30   60.375000  5.649583   3.562500  1028.125000  86.458333
#
#       wind_speed
# 0       5.371667
# 1       5.100000
# 2       4.379167
# 3       5.761250
# 4       6.660833
# ...          ...
# 4315    4.367917
# 4316    2.554583
# 4317    4.385833
# 4318    5.037917
# 4319    4.234167
#
# [4320 rows x 7 columns]

# %%
# Select features (columns) to be involved intro training and predictions
cols = list(dataset_train)[1:7]

# Extract dates (will be used in visualization)
datelist_train = list(dataset_train['Datetime'])
# datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

print('Training set shape == {}'.format(dataset_train.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(cols))
# Out:
# Training set shape == (4320, 7)
# All timestamps == 4320
# Featured selected: ['KW/h', 'temp', 'dew_point', 'pressure', 'humidity', 'wind_speed']

# %% [markdown]
# ## Step #2. Data pre-processing
# Removing all commas and convert data to matrix shape format.

# %%
dataset_train = dataset_train[cols].astype(str)
for i in cols:
    for j in range(0, len(dataset_train)):
        dataset_train[i][j] = dataset_train[i][j].replace(',', '')

dataset_train = dataset_train.astype(float)

# Using multiple features (predictors)
training_set = dataset_train.values

print('Shape of training set == {}.'.format(training_set.shape))
training_set[:1]
# Out:
# Shape of training set == (4320, 6).
# array([[ 1.00073667e+02,  4.42291667e+00, -1.75416667e-01,
#          1.01004167e+03,  7.22500000e+01,  5.37166667e+00]])

# %%
# Feature Scaling
from sklearn.preprocessing import *

sc = MinMaxScaler()
training_set_scaled = sc.fit_transform(training_set)

sc_predict = MinMaxScaler()
sc_predict.fit_transform(training_set[:, 0:1])
# Out:
# array([[0.40334369],
#        [0.86616533],
#        [0.89126436],
#        ...,
#        [0.07682243],
#        [0.01620602],
#        [0.0877532 ]])

# %%
# Creating a data structure with 90 timestamps and 1 output
X_train = []
y_train = []

n_future = 860  # Number of days we want top predict into the future
n_past = 29     # Number of past days we want to use to predict the future

for i in range(n_past, len(training_set_scaled) - n_future +1):
    X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
    y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (3432, 29, 5).
# y_train shape == (3432, 1).

# %% [markdown]
# # PART 2. Create a model. Training
# ## Step #3. Building the LSTM based Neural Network

# %%
# Import Libraries and packages from Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Bidirectional
from keras.layers import Dropout
# from keras.optimizer_v1 import Adam

# %%
# # Initializing the Neural Network based on LSTM
# model = Sequential()

# # Adding 1st LSTM layer
# model.add(LSTM(units=128, activation='relu', return_sequences=True, input_shape=(n_past, dataset_train.shape[1]-1)))

# # Adding 2nd LSTM layer
# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=True))

# # model.add(Dropout(0.2))

# model.add(LSTM(units=128, activation='relu', return_sequences=False))

# # Adding Dropout
# model.add(Dropout(0.2))

# # Output layer
# # model.add(Dense(units=64, activation='relu'))

# model.add(Dense(units=1))

# model = Sequential()
# model.add(LSTM(units=128, activation='relu', input_shape=(n_past, dataset_train.shape[1]-1), return_sequences=True))
# model.add(LSTM(units=128, activation='relu'))
# model.add(Dropout(rate=0.2))
# # model.add(Dense(units=8, activation='relu'))
# model.add(Dense(units=1))
# model.summary()

model = Sequential()
model.add(Bidirectional(LSTM(units=128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True)))
model.add(Bidirectional(LSTM(units=128)))
model.add(Dropout(rate=0.25))
model.add(Dense(units=1))

# Compiling the Neural Network
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Step #4. Start training

# %%
# %%time
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

history = model.fit(X_train, y_train, shuffle=False, epochs=100, callbacks=[es, rlr, mcp, tb], validation_split=0.1, verbose=1, batch_size=64)
# Out:
# Epoch 1/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0449
# Epoch 1: val_loss improved from inf to 0.02444, saving model to weights.h5
# 49/49 [==============================] - 18s 139ms/step - loss: 0.0449 - val_loss: 0.0244 - lr: 0.0010
# Epoch 2/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0283
# Epoch 2: val_loss improved from 0.02444 to 0.02266, saving model to weights.h5
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0283 - val_loss: 0.0227 - lr: 0.0010
# Epoch 3/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0272
# Epoch 3: val_loss improved from 0.02266 to 0.02212, saving model to weights.h5
# 49/49 [==============================] - 5s 95ms/step - loss: 0.0272 - val_loss: 0.0221 - lr: 0.0010
# Epoch 4/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0268
# Epoch 4: val_loss improved from 0.02212 to 0.02126, saving model to weights.h5
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0268 - val_loss: 0.0213 - lr: 0.0010
# Epoch 5/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0260
# Epoch 5: val_loss did not improve from 0.02126
# 49/49 [==============================] - 5s 93ms/step - loss: 0.0260 - val_loss: 0.0216 - lr: 0.0010
# Epoch 6/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 6: val_loss did not improve from 0.02126
# 49/49 [==============================] - 4s 88ms/step - loss: 0.0261 - val_loss: 0.0216 - lr: 0.0010
# Epoch 7/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 7: val_loss did not improve from 0.02126
# 49/49 [==============================] - 4s 89ms/step - loss: 0.0261 - val_loss: 0.0214 - lr: 0.0010
# Epoch 8/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0254
# Epoch 8: val_loss did not improve from 0.02126
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0255 - val_loss: 0.0215 - lr: 0.0010
# Epoch 9/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0256
# Epoch 9: val_loss improved from 0.02126 to 0.02111, saving model to weights.h5
# 49/49 [==============================] - 4s 88ms/step - loss: 0.0256 - val_loss: 0.0211 - lr: 0.0010
# Epoch 10/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0250
# Epoch 10: val_loss improved from 0.02111 to 0.02093, saving model to weights.h5
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0250 - val_loss: 0.0209 - lr: 0.0010
# Epoch 11/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0248
# Epoch 11: val_loss improved from 0.02093 to 0.02034, saving model to weights.h5
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0248 - val_loss: 0.0203 - lr: 0.0010
# Epoch 12/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0245
# Epoch 12: val_loss improved from 0.02034 to 0.01986, saving model to weights.h5
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0245 - val_loss: 0.0199 - lr: 0.0010
# Epoch 13/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0240
# Epoch 13: val_loss improved from 0.01986 to 0.01980, saving model to weights.h5
# 49/49 [==============================] - 4s 89ms/step - loss: 0.0240 - val_loss: 0.0198 - lr: 0.0010
# Epoch 14/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0237
# Epoch 14: val_loss improved from 0.01980 to 0.01924, saving model to weights.h5
# 49/49 [==============================] - 4s 89ms/step - loss: 0.0237 - val_loss: 0.0192 - lr: 0.0010
# Epoch 15/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 15: val_loss improved from 0.01924 to 0.01853, saving model to weights.h5
# 49/49 [==============================] - 4s 92ms/step - loss: 0.0233 - val_loss: 0.0185 - lr: 0.0010
# Epoch 16/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0226
# Epoch 16: val_loss improved from 0.01853 to 0.01720, saving model to weights.h5
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0226 - val_loss: 0.0172 - lr: 0.0010
# Epoch 17/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 17: val_loss improved from 0.01720 to 0.01613, saving model to weights.h5
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0218 - val_loss: 0.0161 - lr: 0.0010
# Epoch 18/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0212
# Epoch 18: val_loss improved from 0.01613 to 0.01445, saving model to weights.h5
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0212 - val_loss: 0.0144 - lr: 0.0010
# Epoch 19/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0207
# Epoch 19: val_loss improved from 0.01445 to 0.01407, saving model to weights.h5
# 49/49 [==============================] - 5s 94ms/step - loss: 0.0206 - val_loss: 0.0141 - lr: 0.0010
# Epoch 20/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0197
# Epoch 20: val_loss improved from 0.01407 to 0.01263, saving model to weights.h5
# 49/49 [==============================] - 5s 100ms/step - loss: 0.0197 - val_loss: 0.0126 - lr: 0.0010
# Epoch 21/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0191
# Epoch 21: val_loss improved from 0.01263 to 0.01225, saving model to weights.h5
# 49/49 [==============================] - 5s 98ms/step - loss: 0.0191 - val_loss: 0.0123 - lr: 0.0010
# Epoch 22/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0189
# Epoch 22: val_loss improved from 0.01225 to 0.01214, saving model to weights.h5
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0189 - val_loss: 0.0121 - lr: 0.0010
# Epoch 23/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0192
# Epoch 23: val_loss improved from 0.01214 to 0.01141, saving model to weights.h5
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0191 - val_loss: 0.0114 - lr: 0.0010
# Epoch 24/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0188
# Epoch 24: val_loss improved from 0.01141 to 0.01137, saving model to weights.h5
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0188 - val_loss: 0.0114 - lr: 0.0010
# Epoch 25/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0186
# Epoch 25: val_loss improved from 0.01137 to 0.01074, saving model to weights.h5
# 49/49 [==============================] - 5s 100ms/step - loss: 0.0185 - val_loss: 0.0107 - lr: 0.0010
# Epoch 26/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0185
# Epoch 26: val_loss did not improve from 0.01074
# 49/49 [==============================] - 5s 98ms/step - loss: 0.0185 - val_loss: 0.0108 - lr: 0.0010
# Epoch 27/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0184
# Epoch 27: val_loss improved from 0.01074 to 0.01022, saving model to weights.h5
# 49/49 [==============================] - 5s 97ms/step - loss: 0.0184 - val_loss: 0.0102 - lr: 0.0010
# Epoch 28/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0184
# Epoch 28: val_loss did not improve from 0.01022
# 49/49 [==============================] - 5s 101ms/step - loss: 0.0183 - val_loss: 0.0107 - lr: 0.0010
# Epoch 29/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0184
# Epoch 29: val_loss improved from 0.01022 to 0.00950, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0184 - val_loss: 0.0095 - lr: 0.0010
# Epoch 30/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 30: val_loss improved from 0.00950 to 0.00941, saving model to weights.h5
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0180 - val_loss: 0.0094 - lr: 0.0010
# Epoch 31/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0178
# Epoch 31: val_loss improved from 0.00941 to 0.00854, saving model to weights.h5
# 49/49 [==============================] - 5s 104ms/step - loss: 0.0178 - val_loss: 0.0085 - lr: 0.0010
# Epoch 32/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0178
# Epoch 32: val_loss did not improve from 0.00854
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0177 - val_loss: 0.0090 - lr: 0.0010
# Epoch 33/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0175
# Epoch 33: val_loss improved from 0.00854 to 0.00848, saving model to weights.h5
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0175 - val_loss: 0.0085 - lr: 0.0010
# Epoch 34/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 34: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 107ms/step - loss: 0.0169 - val_loss: 0.0090 - lr: 0.0010
# Epoch 35/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 35: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0171 - val_loss: 0.0089 - lr: 0.0010
# Epoch 36/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 36: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 103ms/step - loss: 0.0171 - val_loss: 0.0095 - lr: 0.0010
# Epoch 37/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 37: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0170 - val_loss: 0.0096 - lr: 0.0010
# Epoch 38/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 38: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0167 - val_loss: 0.0096 - lr: 0.0010
# Epoch 39/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 39: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 105ms/step - loss: 0.0166 - val_loss: 0.0097 - lr: 0.0010
# Epoch 40/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 40: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0166 - val_loss: 0.0093 - lr: 0.0010
# Epoch 41/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 41: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0161 - val_loss: 0.0091 - lr: 0.0010
# Epoch 42/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0179
# Epoch 42: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0179 - val_loss: 0.0099 - lr: 5.0000e-04
# Epoch 43/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 43: val_loss did not improve from 0.00848
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0162 - val_loss: 0.0113 - lr: 5.0000e-04
# Epoch 43: early stopping
# Wall time: 3min 38s

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend();

# %% [markdown]
# ## PART 3. Make future predictions

# %%
# Generate list of sequence of days for predictions
datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()

'''
Remeber, we have datelist_train from begining.
'''

# Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
datelist_future_ = []
for this_timestamp in datelist_future:
    datelist_future_.append(this_timestamp.date())

# %% [markdown]
# ## Step #5. Make predictions for future dates

# %%
# Perform predictions
predictions_future = model.predict(X_train[-n_future:])

predictions_train = model.predict(X_train[n_past:])

predictions_train1 = model.predict(X_train)

# %% [markdown]
# ## Step #6. Evaluate Metrics

# %%
from sklearn.metrics import *

print('RMSE: ', np.sqrt(mean_squared_error(y_train, predictions_train1)))
print('MSE: ', mean_squared_error(y_train, predictions_train1))
print('MAE: ', mean_absolute_error(y_train, predictions_train1))
print('R2: ', r2_score(y_train, predictions_train1)*100)
# Out:
# RMSE:  0.11873501328716098
# MSE:  0.014098003380302294
# MAE:  0.09595947646375233
# R2:  45.86631054540362

# %%
# Inverse the predictions to original measurements

# ---> Special function: convert <datetime.date> to <Timestamp>
def datetime_to_timestamp(x):
    '''
        x : a given datetime value (datetime.date)
    '''
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')


y_pred_future = sc_predict.inverse_transform(predictions_future)
y_pred_train = sc_predict.inverse_transform(predictions_train)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['value']).set_index(pd.Series(datelist_future))
PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['value']).set_index(pd.Series(datelist_train[2 * n_past + n_future -1:]))

# Convert <datetime.date> to <Timestamp> for PREDCITION_TRAIN
PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)

PREDICTION_TRAIN.head(3)
# Out:
#                  value
# 2010-09-06  113.422638
# 2010-09-07  115.200195
# 2010-09-08  115.365486

# %%
datelist_train = pd.to_datetime(datelist_train)

# %%
dataset_train = dataset_train.set_index(datelist_train)

# %%
dataset_train.head()
# Out:
#                   KW/h      temp  dew_point     pressure   humidity  \
# 2008-03-03  100.073667  4.422917  -0.175417  1010.041667  72.250000
# 2008-03-04  158.292792  3.310000  -0.861250  1026.375000  75.208333
# 2008-03-05  161.450042  4.049167   0.947083  1033.000000  80.291667
# 2008-03-06  158.311500  9.252500   5.157500  1021.916667  75.791667
# 2008-03-07  155.790375  7.638750   2.673333  1010.166667  71.750000
#
#             wind_speed
# 2008-03-03    5.371667
# 2008-03-04    5.100000
# 2008-03-05    4.379167
# 2008-03-06    5.761250
# 2008-03-07    6.660833

# %% [markdown]
# ## Step #6. Visualize the Predictions

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 20, 9

# Plot parameters
START_DATE_FOR_PLOTTING = '2018-01-01'

plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['value'], color='r', label='Predicted Reading')
plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['value'], color='orange', label='Training predictions')
plt.plot(dataset_train.loc[START_DATE_FOR_PLOTTING:].index, dataset_train.loc[START_DATE_FOR_PLOTTING:]['KW/h'], color='b', label='Actual Reading')

plt.axvline(x = min(PREDICTIONS_FUTURE.index), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Predcitions and Acutal Queens Building', family='Arial', fontsize=14, fontweight='bold')
plt.xlabel('Timeline', family='Arial', fontsize=12, fontweight='bold')
plt.ylabel('Energy Reading', family='Arial', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, fontsize=8)
plt.show()
