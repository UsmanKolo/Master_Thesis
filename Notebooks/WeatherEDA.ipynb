# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,9)
plt.style.use('bmh')
import numpy as np


data = pd.read_csv('C:\\Users\\moham\\OneDrive - De Montfort University\\Final Project\\Master_Thesis\\Dataset\\Weather.csv', index_col=1, parse_dates=True)

data.tail()
# Out:
#                              dt  timezone  city_name        lat       lon  \
# dt_iso
# 2022-03-01 19:00:00  1646161200         0  Leicester  52.636878 -1.139759
# 2022-03-01 20:00:00  1646164800         0  Leicester  52.636878 -1.139759
# 2022-03-01 21:00:00  1646168400         0  Leicester  52.636878 -1.139759
# 2022-03-01 22:00:00  1646172000         0  Leicester  52.636878 -1.139759
# 2022-03-01 23:00:00  1646175600         0  Leicester  52.636878 -1.139759
#
#                      temp  visibility  dew_point  feels_like  temp_min  ...  \
# dt_iso                                                                  ...
# 2022-03-01 19:00:00  6.67         NaN       4.83        3.32      5.75  ...
# 2022-03-01 20:00:00  6.30         NaN       4.62        2.91      5.75  ...
# 2022-03-01 21:00:00  6.10         NaN       4.43        2.52      5.16  ...
# 2022-03-01 22:00:00  5.87         NaN       4.36        2.59      5.12  ...
# ...

# %%
data.describe().transpose()
# Out:
#                count          mean           std           min           25%  \
# dt          124176.0  1.422661e+09  1.290480e+08  1.199146e+09  1.310903e+09
# timezone    124176.0  2.079706e+03  1.778142e+03  0.000000e+00  0.000000e+00
# lat         124176.0  5.263688e+01  1.421091e-14  5.263688e+01  5.263688e+01
# lon         124176.0 -1.139759e+00  0.000000e+00 -1.139759e+00 -1.139759e+00
# temp        124176.0  1.040077e+01  5.906019e+00 -1.072000e+01  6.140000e+00
# visibility       0.0           NaN           NaN           NaN           NaN
# dew_point   124176.0  7.248109e+00  4.999126e+00 -3.523000e+01  3.550000e+00
# feels_like  124176.0  8.762749e+00  7.195326e+00 -1.294000e+01  3.160000e+00
# temp_min    124176.0  9.365455e+00  5.912856e+00 -1.375000e+01  5.130000e+00
# temp_max    124176.0  1.146047e+01  6.006574e+00 -8.410000e+00  7.210000e+00
# pressure    124176.0  1.014386e+03  1.138366e+01  9.590000e+02  1.008000e+03
# ...

# %%
len(data)
# Out:
# 124176

# %%
data.isna().sum()
# Out:
# dt                          0
# timezone                    0
# city_name                   0
# lat                         0
# lon                         0
# temp                        0
# visibility             124176
# dew_point                   0
# feels_like                  0
# temp_min                    0
# temp_max                    0
# pressure                    0
# sea_level              124176
# grnd_level             124176
# humidity                    0
# wind_speed                  0
# wind_deg                    0
# wind_gust              121062
# rain_1h                105181
# rain_3h                124176
# snow_1h                123678
# snow_3h                124176
# clouds_all                  0
# weather_id                  0
# weather_main                0
# weather_description         0
# weather_icon                0
# dtype: int64

# %%
data = data.dropna(how='any', axis=1)

# %%
data.describe().transpose()
# Out:
#                count          mean           std           min           25%  \
# dt          124176.0  1.422661e+09  1.290480e+08  1.199146e+09  1.310903e+09
# timezone    124176.0  2.079706e+03  1.778142e+03  0.000000e+00  0.000000e+00
# lat         124176.0  5.263688e+01  1.421091e-14  5.263688e+01  5.263688e+01
# lon         124176.0 -1.139759e+00  0.000000e+00 -1.139759e+00 -1.139759e+00
# temp        124176.0  1.040077e+01  5.906019e+00 -1.072000e+01  6.140000e+00
# dew_point   124176.0  7.248109e+00  4.999126e+00 -3.523000e+01  3.550000e+00
# feels_like  124176.0  8.762749e+00  7.195326e+00 -1.294000e+01  3.160000e+00
# temp_min    124176.0  9.365455e+00  5.912856e+00 -1.375000e+01  5.130000e+00
# temp_max    124176.0  1.146047e+01  6.006574e+00 -8.410000e+00  7.210000e+00
# pressure    124176.0  1.014386e+03  1.138366e+01  9.590000e+02  1.008000e+03
# humidity    124176.0  8.200810e+01  1.260884e+01  2.000000e+00  7.400000e+01
# ...

# %%
data.plot(subplots=True, figsize=(13,9))
# Out:
# array([<AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>], dtype=object)

# %%
data['weather_id'].unique()
# Out:
# array([804, 803, 500, 501, 801, 802, 800, 600, 601, 502, 503, 602],
#       dtype=int64)

# %%
data['weather_main'].unique()
# Out:
# array(['Clouds', 'Rain', 'Clear', 'Snow'], dtype=object)

# %%
data['weather_description'].unique()
# Out:
# array(['overcast clouds', 'broken clouds', 'light rain', 'moderate rain',
#        'few clouds', 'scattered clouds', 'sky is clear', 'light snow',
#        'snow', 'heavy intensity rain', 'very heavy rain', 'heavy snow'],
#       dtype=object)

# %%
data['weather_icon'].unique()
# Out:
# array(['04n', '04d', '10d', '10n', '02n', '03n', '03d', '01d', '02d',
#        '01n', '13d', '13n'], dtype=object)

# %%
data = data.drop(['lat', 'lon', 'weather_id', 'dt', 'timezone', 'city_name', 'clouds_all', 'wind_deg'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 124176 entries, 2008-01-01 00:00:00 to 2022-03-01 23:00:00
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   temp                 124176 non-null  float64
#  1   dew_point            124176 non-null  float64
#  2   feels_like           124176 non-null  float64
#  3   temp_min             124176 non-null  float64
#  4   temp_max             124176 non-null  float64
#  5   pressure             124176 non-null  int64
#  6   humidity             124176 non-null  int64
#  7   wind_speed           124176 non-null  float64
#  8   weather_main         124176 non-null  object
#  9   weather_description  124176 non-null  object
#  10  weather_icon         124176 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 11.4+ MB

# %%
data.plot(subplots=True, figsize=(13,9))
# Out:
# array([<AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>],
#       dtype=object)

# %%
data.describe().transpose()
# Out:
#                count         mean        std     min      25%      50%  \
# temp        124176.0    10.400765   5.906019  -10.72     6.14    10.23
# dew_point   124176.0     7.248109   4.999126  -35.23     3.55     7.48
# feels_like  124176.0     8.762749   7.195326  -12.94     3.16     9.56
# temp_min    124176.0     9.365455   5.912856  -13.75     5.13     9.23
# temp_max    124176.0    11.460467   6.006574   -8.41     7.21    11.25
# pressure    124176.0  1014.386307  11.383661  959.00  1008.00  1015.00
# humidity    124176.0    82.008101  12.608843    2.00    74.00    85.00
# wind_speed  124176.0     4.431663   2.150646    0.03     2.79     4.15
#
#                 75%      max
# temp          14.47    34.88
# dew_point     11.04    22.21
# feels_like    14.13    37.29
# temp_min      13.54    33.23
# temp_max      15.52    37.43
# pressure    1022.00  1049.00
# humidity      92.00   100.00
# wind_speed     5.74    15.97

# %%
from sklearn.preprocessing import *

# encode_features = ('weather_main', 'weather_description', 'weather_icon')

data["weather_main"] = data["weather_main"].astype('category')
data["weather_description"] = data["weather_description"].astype('category')
data["weather_icon"] = data["weather_icon"].astype('category')


data["weather_main"] = data["weather_main"].cat.codes
data["weather_description"] = data["weather_description"].cat.codes
data["weather_icon"] = data["weather_icon"].cat.codes

# le = LabelEncoder()

# for label in encode_features:
#     le.fit_transform(label)


data
# Out:
#                      temp  dew_point  feels_like  temp_min  temp_max  \
# dt_iso
# 2008-01-01 00:00:00  7.38       6.79        5.53      6.04      8.21
# 2008-01-01 01:00:00  6.49       6.05        4.51      6.04      7.13
# 2008-01-01 02:00:00  6.45       6.01        4.54      5.94      7.06
# 2008-01-01 03:00:00  6.74       6.45        5.05      5.04      7.25
# 2008-01-01 04:00:00  6.64       6.35        5.08      5.59      7.21
# ...                   ...        ...         ...       ...       ...
# 2022-03-01 19:00:00  6.67       4.83        3.32      5.75      7.23
# 2022-03-01 20:00:00  6.30       4.62        2.91      5.75      7.09
# 2022-03-01 21:00:00  6.10       4.43        2.52      5.16      7.09
# 2022-03-01 22:00:00  5.87       4.36        2.59      5.12      6.62
# 2022-03-01 23:00:00  5.63       4.43        2.03      5.04      6.23
#
#                      pressure  humidity  wind_speed  weather_main  \
# dt_iso
# ...

# %%
data.plot(subplots=True, figsize=(13,9))
# Out:
# array([<AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>, <AxesSubplot:xlabel='dt_iso'>,
#        <AxesSubplot:xlabel='dt_iso'>], dtype=object)

# %%
data.corr()
# Out:
#                          temp  dew_point  feels_like  temp_min  temp_max  \
# temp                 1.000000   0.898071    0.990484  0.992035  0.992056
# dew_point            0.898071   1.000000    0.910858  0.893425  0.884041
# feels_like           0.990484   0.910858    1.000000  0.980642  0.983528
# temp_min             0.992035   0.893425    0.980642  1.000000  0.979637
# temp_max             0.992056   0.884041    0.983528  0.979637  1.000000
# pressure             0.040913  -0.018488    0.065963  0.022709  0.055066
# humidity            -0.487700  -0.059604   -0.441553 -0.479349 -0.498470
# wind_speed           0.028512   0.010608   -0.039593  0.058769  0.006023
# weather_main         0.040119   0.127021    0.037724  0.052677  0.032351
# weather_description -0.018312  -0.013544   -0.015183 -0.019252 -0.018698
# weather_icon        -0.015304   0.106397   -0.008470 -0.000716 -0.030215
#
#                      pressure  humidity  wind_speed  weather_main  \
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12,12))
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
sns.set(font_scale=1)
sns.heatmap(corr, mask=mask, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
plt.xticks(rotation='vertical')
plt.yticks(rotation='horizontal')
plt.xlabel('Features',fontsize=20, ha='center')
plt.ylabel('Features',fontsize=20, ha='center')
plt.title('Heatmap Between Features of Weather Dataset',fontsize=20, ha='center')
plt.tick_params(labelsize=16)
plt.ylim(11, 0)
plt.tight_layout()
# Out:
# <ipython-input-22-3c811c4efdaf>:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr, dtype=np.bool))

# %%
data['temp'].loc['2012-08':'2012-09'].plot(label='temp')
data.humidity.loc['2012-08':'2012-09'].plot(label='humidty')
plt.title('Negative Correlation', fontweight='bold',  fontsize=16)
plt.xlabel('Date', fontweight='bold',  fontsize=14)
plt.ylabel('Unit', fontweight='bold',  fontsize=14)
plt.legend(shadow=True)

# %%
data['temp'].loc['2012-08':'2012-09'].plot(label='temp')
data.dew_point.loc['2012-08':'2012-09'].plot(label='dew point')
plt.title('Positive Correlation', fontweight='bold',  fontsize=16)
plt.xlabel('Date', fontweight='bold',  fontsize=14)
plt.ylabel('Unit', fontweight='bold',  fontsize=14)
plt.legend(shadow=True)

# %%
data.describe().transpose()
# Out:
#                         count         mean        std     min      25%  \
# temp                 124176.0    10.400765   5.906019  -10.72     6.14
# dew_point            124176.0     7.248109   4.999126  -35.23     3.55
# feels_like           124176.0     8.762749   7.195326  -12.94     3.16
# temp_min             124176.0     9.365455   5.912856  -13.75     5.13
# temp_max             124176.0    11.460467   6.006574   -8.41     7.21
# pressure             124176.0  1014.386307  11.383661  959.00  1008.00
# humidity             124176.0    82.008101  12.608843    2.00    74.00
# wind_speed           124176.0     4.431663   2.150646    0.03     2.79
# weather_main         124176.0     1.060189   0.515905    0.00     1.00
# weather_description  124176.0     5.409218   3.054708    0.00     4.00
# weather_icon         124176.0     5.732179   2.278740    0.00     5.00
#
#                          50%      75%      max
# temp                   10.23    14.47    34.88
# ...

# %%
from sklearn.preprocessing import *

scaler = MinMaxScaler()
scaled = scaler.fit_transform(data)

# %%
preprocess = pd.DataFrame(scaled, columns=data.columns, index=data.index)

# %%
preprocess.describe().transpose()
# Out:
#                         count      mean       std  min       25%       50%  \
# temp                 124176.0  0.463175  0.129518  0.0  0.369737  0.459430
# dew_point            124176.0  0.739521  0.087032  0.0  0.675139  0.743558
# feels_like           124176.0  0.432067  0.143248  0.0  0.320526  0.447939
# temp_min             124176.0  0.492028  0.125859  0.0  0.401873  0.489144
# temp_max             124176.0  0.433474  0.131033  0.0  0.340750  0.428883
# pressure             124176.0  0.615403  0.126485  0.0  0.544444  0.622222
# humidity             124176.0  0.816409  0.128662  0.0  0.734694  0.846939
# wind_speed           124176.0  0.276139  0.134921  0.0  0.173149  0.258469
# weather_main         124176.0  0.353396  0.171968  0.0  0.333333  0.333333
# weather_description  124176.0  0.491747  0.277701  0.0  0.363636  0.636364
# weather_icon         124176.0  0.521107  0.207158  0.0  0.454545  0.545455
#
#                           75%  max
# ...

# %%
sc = StandardScaler()
xsc = sc.fit_transform(data)

preprocess1 = pd.DataFrame(xsc, columns=data.columns, index=data.index)
preprocess1.describe().transpose()
# Out:
#                         count          mean       std       min       25%  \
# temp                 124176.0 -2.380378e-17  1.000004 -3.576157 -0.721430
# dew_point            124176.0 -1.345829e-16  1.000004 -8.497141 -0.739754
# feels_like           124176.0 -1.171878e-16  1.000004 -3.016241 -0.778668
# temp_min             124176.0  4.394543e-17  1.000004 -3.909371 -0.716316
# temp_max             124176.0 -2.188116e-16  1.000004 -3.308133 -0.707639
# pressure             124176.0  1.657109e-15  1.000004 -4.865441 -0.561009
# humidity             124176.0  4.669202e-17  1.000004 -6.345421 -0.635120
# wind_speed           124176.0  8.239769e-18  1.000004 -2.046679 -0.763338
# weather_main         124176.0  3.021249e-17  1.000004 -2.055017 -0.116667
# weather_description  124176.0  2.706535e-17  1.000004 -1.770788 -0.461328
# weather_icon         124176.0  1.280597e-16  1.000004 -2.515514 -0.321310
#
#                           50%       75%       max
# ...

# %%
def correlation(data, threshold):
    col_corr = set()
    corr_matrix = data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
correlation(data, 0.5)
# Out:
# {'dew_point', 'feels_like', 'temp_max', 'temp_min', 'weather_icon'}

# %%
from sklearn.model_selection import *

X = data.drop('temp', axis=1)
y = data['temp']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train.shape, y_train.shape
# Out:
# ((99340, 10), (99340,))

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(objective='reg:squarederror',
    n_estimators=1000,
    learning_rate=0.1,
    subsample=0.5,
    colsample_bytree=1, 
    max_depth=7,
)

xgb.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
        verbose=False)
# Out:
# C:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=7, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=5000, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=0.5,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
from xgboost import plot_importance

feature_importance = plot_importance(xgb, height=0.9)
feature_importance
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
data.head()
# Out:
#                      temp  dew_point  feels_like  temp_min  temp_max  \
# dt_iso
# 2008-01-01 00:00:00  7.38       6.79        5.53      6.04      8.21
# 2008-01-01 01:00:00  6.49       6.05        4.51      6.04      7.13
# 2008-01-01 02:00:00  6.45       6.01        4.54      5.94      7.06
# 2008-01-01 03:00:00  6.74       6.45        5.05      5.04      7.25
# 2008-01-01 04:00:00  6.64       6.35        5.08      5.59      7.21
#
#                      pressure  humidity  wind_speed  weather_main  \
# dt_iso
# 2008-01-01 00:00:00      1026        96        2.76             1
# 2008-01-01 01:00:00      1026        97        2.70             1
# 2008-01-01 02:00:00      1025        97        2.60             1
# 2008-01-01 03:00:00      1025        98        2.39             1
# 2008-01-01 04:00:00      1024        98        2.22             1
#
#                      weather_description  weather_icon
# dt_iso
# 2008-01-01 00:00:00                    7             7
# ...

# %%
from sklearn.ensemble import *

cols = data.columns

regr = RandomForestRegressor(max_depth=7, n_estimators=100)
regr.fit(data[cols[1:len(cols)-1]], data['temp'])

importances = regr.feature_importances_*100

plt.figure(figsize=(12,12))
sns.barplot(cols[1:len(cols)-1],importances)
plt.xlabel('Features',fontsize=18, ha='center')
plt.ylabel('%',fontsize=25, ha='center')
plt.title('Feature Importance',fontsize=25, ha='center')
plt.xticks(rotation='vertical')
plt.tick_params(labelsize=18)
# plt.savefig('C:/Users/Anton/Desktop/Exjobb MSC/graph_ex/Feature_Importance.PNG')
# Out:
# C:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
